# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/',
#  'https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/
# https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/posts',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/spaces',
#  '/models',
#  '/Qwen/QwQ-32B',
#  '/deepseek-ai/DeepSeek-R1',
#  '/microsoft/Phi-4-multimodal-instruct',
#  '/Wan-AI/Wan2.1-T2V-14B',
#  '/CohereForAI/aya-vision-8b',
#  '/models',
#  '/spaces/ASLP-lab/DiffRhythm',
#  '/spaces/Wan-AI/Wan2.1',
#  '/spaces/nanotron/ultrascale-playbook',
#  '/spaces/Qwen/QwQ-32B-Demo',
#  '/spaces/black-forest-labs/FLUX.1-dev',
#  '/spaces',
#  '/datasets/facebook/natural_reasoning',
#  '/datasets/FreedomIntelligence/medical-o1-reasoning-SFT',
#  '/datasets/Congliu/Chinese-DeepSeek-R1-Distill-data-110k',
#  '/datasets/GeneralReasoning/GeneralThought-195K',
#  '/datasets/KodCode/KodCode-V1',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/tasks',
#  'https://ui.endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'},
#   {'type': 'blog page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'company social page',
#    'url': 'https://www.linkedin.com/company/huggingface/'},
#   {'type': 'community forum', 'url': 'https://discuss.huggingface.co'},
#   {'type': 'github page', 'url': 'https://github.com/huggingface'},
#   {'type': 'twitter page', 'url': 'https://twitter.com/huggingface'},
#   {'type': 'status page', 'url': 'https://status.huggingface.co/'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'join page', 'url': 'https://huggingface.co/join'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# Qwen/QwQ-32B
# Updated
# about 1 hour ago
# •
# 132k
# •
# 1.81k
# deepseek-ai/DeepSeek-R1
# Updated
# 15 days ago
# •
# 3.43M
# •
# 11.1k
# microsoft/Phi-4-multimodal-instruct
# Updated
# 3 days ago
# •
# 303k
# •
# 1.06k
# Wan-AI/Wan2.1-T2V-14B
# Updated
# 12 days ago
# •
# 191k
# •
# 964
# CohereForAI/aya-vision-8b
# Updated
# 6 days ago
# •
# 144k
# •
# 220
# Browse 1M+ models
# Spaces
# Running
# on
# Zero
# 337
# 337
# Di♪♪Rhythm
# 🎶
# Blazingly Fast and Embarrassingly Simple Song Generation
# Running
# 1.06k
# 1.06k
# Wan2.1
# 💻
# Wan: Open and Advanced Large-Scale Video Generative Models
# Running
# 2.17k
# 2.17k
# The Ultra-Scale Playbook
# 🌌
# The ultimate guide to training LLM on large GPU Clusters
# Running
# 278
# 278
# QwQ 32B Demo
# 🌖
# Generate text responses based on user input
# Running
# on
# Zero
# 7.74k
# 7.74k
# FLUX.1 [dev]
# 🖥
# Generate images from text prompts
# Browse 400k+ applications
# Datasets
# facebook/natural_reasoning
# Updated
# 17 days ago
# •
# 9.01k
# •
# 362
# FreedomIntelligence/medical-o1-reasoning-SFT
# Updated
# 16 days ago
# •
# 26.7k
# •
# 406
# Congliu/Chinese-DeepSeek-R1-Distill-data-110k
# Updated
# 18 days ago
# •
# 6.87k
# •
# 489
# GeneralReasoning/GeneralThought-195K
# Updated
# about 3 hours ago
# •
# 697
# •
# 59
# KodCode/KodCode-V1
# Updated
# about 19 hours ago
# •
# 2.19k
# •
# 55
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 391 models
# •
# 2.76k followers
# AI at Meta
# Enterprise
# company
# •
# 2.07k models
# •
# 5k followers
# Amazon
# company
# •
# 20 models
# •
# 2.83k followers
# Google
# company
# •
# 959 models
# •
# 8.65k followers
# Intel
# company
# •
# 219 models
# •
# 2.32k followers
# Microsoft
# company
# •
# 362 models
# •
# 10.1k followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 133 followers
# Writer
# Enterprise
# company
# •
# 20 models
# •
# 248 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 140,930
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 27,945
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,157
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,412
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,454
# Fast tokenizers optimized for research & production
# TRL
# 12,381
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,166
# State-of-the-art ML running directly in your browser
# smolagents
# 14,260
# Smol library to build great agents in Python
# PEFT
# 17,691
# Parameter-efficient finetuning for large language models
# Datasets
# 19,758
# Access & share datasets for any ML tasks
# Text Generation Inference
# 9,864
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,450
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 24,659
# AI & ML interests
# The AI community building the future.
# Recent Activity
# hlky
# new
# activity
# about 3 hours ago
# huggingface/documentation-images:
# Upload fantasy_landscape.png
# mishig
# updated
# a Space
# about 3 hours ago
# huggingface/inference-playground
# hlky
# new
# activity
# about 3 hours ago
# huggingface/documentation-images:
# Remote vae
# View all activity
# Articles
# Yay! Organizations can now publish blog Articles
# Jan 20
# •
# 36
# Team members
# 210
# +176
# +163
# +142
# +132
# +112
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 277k
# •
# •
# 37
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 12.4M
# •
# •
# 640
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 1.62M
# •
# •
# 174
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# Updated
# Dec 19, 2023
# •
# 7.65M
# •
# •
# 705
# spaces
# 24
# Sort:
# 		Recently updated
# pinned
# Running
# 71
# Number Tokenization Blog
# 📈
# Explore how tokenization affects arithmetic in LLMs
# huggingface
# Dec 14, 2024
# Running
# 109
# Inference Playground
# 🔋
# Chat with AI assistants
# huggingface
# about 3 hours ago
# Running
# 313
# AI Deadlines
# ⚡
# Schedule tasks efficiently using AI-generated deadlines
# huggingface
# 2 days ago
# Running
# 533
# Open Source Ai Year In Review 2024
# 😻
# What happened in open-source AI this year, and what’s next?
# huggingface
# Jan 8
# Running
# 217
# paper-central
# ⚡
# Explore and manage research papers
# huggingface
# Dec 13, 2024
# Running
# on
# TPU v5e
# 9
# Keras Chatbot Battle
# 💬
# Interact with multiple chatbots simultaneously
# huggingface
# Dec 5, 2024
# Expand 24
# 							spaces
# models
# 16
# Sort:
# 		Recently updated
# huggingface/timesfm-tourism-monthly
# Updated
# Dec 9, 2024
# •
# 269
# •
# 1
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 4.17k
# •
# •
# 58
# huggingface/falcon-40b-gptq
# Text Generation
# •
# Updated
# Jun 14, 2023
# •
# 54
# •
# 12
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 55.7k
# •
# 9
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# Updated
# Mar 22, 2023
# •
# 354
# •
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 37.2k
# •
# 6
# huggingface/time-series-transformer-tourism-monthly
# Updated
# Feb 23, 2023
# •
# 5.63k
# •
# 19
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 68
# •
# 4
# huggingface/CodeBERTa-small-v1
# Fill-Mask
# •
# Updated
# Jun 27, 2022
# •
# 35k
# •
# 79
# huggingface/test-model-repo
# Updated
# Nov 19, 2021
# •
# 1
# Expand 16
# 							models
# datasets
# 42
# Sort:
# 		Recently updated
# huggingface/documentation-images
# Viewer
# •
# Updated
# 4 days ago
# •
# 50
# •
# 4.79M
# •
# 53
# huggingface/policy-docs
# Updated
# 5 days ago
# •
# 1.99k
# •
# 9
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# 6 days ago
# •
# 1.57k
# •
# 4.94k
# •
# 16
# huggingface/gemini-results-2025-03-03
# Viewer
# •
# Updated
# 7 days ago
# •
# 17
# •
# 17
# huggingface/gemini-results-2025-02-28
# Viewer
# •
# Updated
# 10 days ago
# •
# 21
# •
# 23
# huggingface/gemini-results-2025-02-27
# Viewer
# •
# Updated
# 10 days ago
# •
# 24
# •
# 22
# huggingface/gemini-results-2025-02-25
# Viewer
# •
# Updated
# 13 days ago
# •
# 32
# •
# 35
# huggingface/gemini-results-2025-02-24
# Viewer
# •
# Updated
# 14 days ago
# •
# 32
# •
# 45
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# 14 days ago
# •
# 68
# •
# 632
# •
# 5
# huggingface/gemini-results-2025-02-21
# Viewer
# •
# Updated
# 16 days ago
# •
# 29
# •
# 105
# •
# 1
# Expand 42
# 							datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# enterprise page
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Enterprise Hub
# Enterprise-ready version of the world’s leading AI platform
# Subscribe to
# Enterprise Hub
# for $20/user/month with your Hub organization
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU.
# ZeroGPU Quota Boost
# All organization members get 5x more ZeroGPU quota to get the most of Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Enterprise Hub
# or
# Talk to sales
# NVIDIA
# Enterprise
# company
# •
# 291 models
# •
# 18.1k followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 285 followers
# AI at Meta
# Enterprise
# company
# •
# 2.07k models
# •
# 5k followers
# Writer
# Enterprise
# company
# •
# 20 models
# •
# 248 followers
# ServiceNow-AI
# Enterprise
# company
# •
# 179 followers
# Fidelity Investments
# Enterprise
# company
# •
# 126 followers
# Procter & Gamble
# Enterprise
# company
# •
# 72 followers
# IBM Granite
# Enterprise
# company
# •
# 94 models
# •
# 1.23k followers
# Chegg Inc
# Enterprise
# company
# •
# 83 followers
# creditkarma
# Enterprise
# company
# •
# 49 followers
# Johnson & Johnson
# Enterprise
# company
# •
# 54 followers
# Stability AI
# Enterprise
# company
# •
# 103 models
# •
# 18.2k followers
# Novo Nordisk
# Enterprise
# company
# •
# 62 followers
# Kakao Corp.
# Enterprise
# company
# •
# 3 models
# •
# 90 followers
# Meta Llama
# Enterprise
# company
# •
# 57 models
# •
# 31k followers
# Snowflake
# Enterprise
# company
# •
# 14 models
# •
# 451 followers
# Orange
# Enterprise
# company
# •
# 7 models
# •
# 185 followers
# Arm
# Enterprise
# company
# •
# 154 followers
# Toyota Research Institute
# Enterprise
# company
# •
# 10 models
# •
# 102 followers
# Jusbrasil
# Enterprise
# company
# •
# 83 followers
# Mistral AI_
# Enterprise
# company
# •
# 23 models
# •
# 6.01k followers
# Technology Innovation Institute
# Enterprise
# company
# •
# 65 models
# •
# 1.24k followers
# Nutanix
# Enterprise
# company
# •
# 262 models
# •
# 63 followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 133 followers
# MiniMax
# Enterprise
# company
# •
# 2 models
# •
# 563 followers
# Liberty Mutual
# Enterprise
# company
# •
# 44 followers
# Widn AI
# Enterprise
# company
# •
# 40 followers
# Gretel.ai
# Enterprise
# company
# •
# 9 models
# •
# 106 followers
# Shopify
# Enterprise
# company
# •
# 416 followers
# AMD
# Enterprise
# company
# •
# 99 models
# •
# 1.38k followers
# Together
# Enterprise
# company
# •
# 32 models
# •
# 536 followers
# Xsolla
# Enterprise
# company
# •
# 110 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 131 followers
# Mercedes-Benz AG
# Enterprise
# company
# •
# 137 followers
# H2O.ai
# Enterprise
# company
# •
# 71 models
# •
# 404 followers
# Aledade Inc
# Enterprise
# company
# •
# 63 followers
# Virtusa Corporation
# Enterprise
# company
# •
# 61 followers
# HiddenLayer
# Enterprise
# company
# •
# 1 model
# •
# 61 followers
# Arcee AI
# Enterprise
# company
# •
# 155 models
# •
# 455 followers
# StepFun
# Enterprise
# company
# •
# 7 models
# •
# 762 followers
# BCG X
# Enterprise
# company
# •
# 35 followers
# Adyen
# Enterprise
# company
# •
# 51 followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# pricing page
# Webpage Title:
# Hugging Face – Pricing
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Pricing
# Leveling up AI collaboration and compute.
# Users and organizations already use the Hub as a collaboration platform,
# we’re making it easy to seamlessly and scalably launch ML compute directly from the Hub.
# HF Hub
# Collaborate on Machine Learning
# Host unlimited public models, datasets
# Create unlimited orgs with no member limits
# Access the latest ML tools and open source
# Community support
# Forever
# Free
# PRO
# Pro Account
# Unlock advanced HF features
# ZeroGPU and Dev Mode for Spaces
# Free credits across all Inference Providers
# Get early access to upcoming features
# Show your support with a Pro badge
# Subscribe for
# $9
# /month
# Enterprise Hub
# Accelerate your AI roadmap
# SSO and SAML support
# Select data location with Storage Regions
# Precise actions reviews with Audit logs
# Granular access control with Resource groups
# Centralized token control and approval
# Dataset Viewer for private datasets
# Advanced compute options for Spaces
# 5x more ZeroGPU quota for all org members
# Deploy Inference on your own Infra
# Managed billing with yearly commits
# Priority support
# Starting at
# $20
# per user per month
# Spaces Hardware
# Upgrade your Space compute
# Free CPUs
# Build more advanced Spaces
# 7 optimized hardware available
# From CPU to GPU to Accelerators
# Starting at
# $0
# /hour
# Inference Endpoints
# Deploy models on fully managed infrastructure
# Deploy dedicated Endpoints in seconds
# Keep your costs low
# Fully-managed autoscaling
# Enterprise security
# Starting at
# $0.032
# /hour
# Need support to accelerate AI in your organization? View our
# Expert Support
# .
# Hugging Face Hub
# free
# The HF Hub is the central place to explore, experiment, collaborate and build technology with Machine
# 					Learning.
# Join the open source Machine Learning movement!
# →
# Sign Up
# Create with ML
# Packed with ML features, like model eval, dataset viewer and much more.
# Collaborate
# Git based and designed for collaboration at its core.
# Play and learn
# Learn by experimenting and sharing with our awesome community.
# Build your ML portfolio
# Share your work with the world and build your own ML profile.
# Spaces Hardware
# Starting at $0
# Spaces are one of the most popular ways to share ML applications and demos with the world.
# Upgrade your Spaces with our selection of custom on-demand hardware:
# →
# Get started with Spaces
# Name
# CPU
# Memory
# Accelerator
# VRAM
# Hourly price
# CPU Basic
# 2 vCPU
# 16 GB
# -
# -
# FREE
# CPU Upgrade
# 8 vCPU
# 32 GB
# -
# -
# $0.03
# Nvidia T4 - small
# 4 vCPU
# 15 GB
# Nvidia T4
# 16 GB
# $0.40
# Nvidia T4 - medium
# 8 vCPU
# 30 GB
# Nvidia T4
# 16 GB
# $0.60
# 1x Nvidia L4
# 8 vCPU
# 30 GB
# Nvidia L4
# 24 GB
# $0.80
# 4x Nvidia L4
# 48 vCPU
# 186 GB
# Nvidia L4
# 96 GB
# $3.80
# 1x Nvidia L40S
# 8 vCPU
# 62 GB
# Nvidia L4
# 48 GB
# $1.80
# 4x Nvidia L40S
# 48 vCPU
# 382 GB
# Nvidia L4
# 192 GB
# $8.30
# 8x Nvidia L40S
# 192 vCPU
# 1534 GB
# Nvidia L4
# 384 GB
# $23.50
# Nvidia A10G - small
# 4 vCPU
# 15 GB
# Nvidia A10G
# 24 GB
# $1.00
# Nvidia A10G - large
# 12 vCPU
# 46 GB
# Nvidia A10G
# 24 GB
# $1.50
# 2x Nvidia A10G - large
# 24 vCPU
# 92 GB
# Nvidia A10G
# 48 GB
# $3.00
# 4x Nvidia A10G - large
# 48 vCPU
# 184 GB
# Nvidia A10G
# 96 GB
# $5.00
# Nvidia A100 - large
# 12 vCPU
# 142 GB
# Nvidia A100
# 80 GB
# $4.00
# TPU v5e 1x1
# 22 vCPU
# 44 GB
# Google TPU v5e
# 16 GB
# $1.20
# TPU v5e 2x2
# 110 vCPU
# 186 GB
# Google TPU v5e
# 64 GB
# $4.75
# TPU v5e 2x4
# 220 vCPU
# 380 GB
# Google TPU v5e
# 128 GB
# $9.50
# Custom
# on demand
# on demand
# on demand
# on demand
# on demand
# Spaces Persistent Storage
# All Spaces get ephemeral storage for free but you can upgrade and add persistent storage at any time.
# Name
# Storage
# Monthly price
# Small
# 20 GB
# $5
# Medium
# 150 GB
# $25
# Large
# 1 TB
# $100
# Building something cool as a side project? We also offer community GPU grants.
# Inference Endpoints
# Starting at $0.033/hour
# Inference Endpoints (dedicated) offers a secure production solution to easily deploy any ML model on dedicated
# 					and autoscaling infrastructure, right from the HF Hub.
# →
# Learn more
# CPU
# instances
# Provider
# Architecture
# vCPUs
# Memory
# Hourly rate
# aws
# Intel Sapphire Rapids
# 1
# 2GB
# $0.03
# 2
# 4GB
# $0.07
# 4
# 8GB
# $0.13
# 8
# 16GB
# $0.27
# 16
# 32GB
# $0.54
# azure
# Intel Xeon
# 1
# 2GB
# $0.06
# 2
# 4GB
# $0.12
# 4
# 8GB
# $0.24
# 8
# 16GB
# $0.48
# gcp
# Intel Sapphire Rapids
# 1
# 2GB
# $0.05
# 2
# 4GB
# $0.10
# 4
# 8GB
# $0.20
# 8
# 16GB
# $0.40
# Accelerator
# instances
# Provider
# Architecture
# Topology
# Accelerator Memory
# Hourly rate
# aws
# Inf2
# 															Neuron
# x1
# 14.5GB
# $0.75
# x12
# 760GB
# $12.00
# gcp
# TPU
# 															v5e
# 1x1
# 16GB
# $1.20
# 2x2
# 64GB
# $4.75
# 2x4
# 128GB
# $9.50
# GPU
# instances
# Provider
# Architecture
# GPUs
# GPU Memory
# Hourly rate
# aws
# NVIDIA T4
# 1
# 14GB
# $0.50
# 4
# 56GB
# $3.00
# aws
# NVIDIA L4
# 1
# 24GB
# $0.80
# 4
# 96GB
# $3.80
# aws
# NVIDIA L40S
# 1
# 48GB
# $1.80
# 4
# 192GB
# $8.30
# 8
# 384GB
# $23.50
# aws
# NVIDIA A10G
# 1
# 24GB
# $1.00
# 4
# 96GB
# $5.00
# aws
# NVIDIA A100
# 1
# 80GB
# $4.00
# 2
# 160GB
# $8.00
# 4
# 320GB
# $16.00
# 8
# 640GB
# $32.00
# gcp
# NVIDIA T4
# 1
# 16GB
# $0.50
# gcp
# NVIDIA L4
# 1
# 24GB
# $0.70
# 4
# 96GB
# $3.80
# gcp
# NVIDIA A100
# 1
# 80GB
# $3.60
# 2
# 160GB
# $7.20
# 4
# 320GB
# $14.40
# 8
# 640GB
# $28.80
# gcp
# NVIDIA H100
# 1
# 80GB
# $10.00
# 2
# 160GB
# $20.00
# 4
# 320GB
# $40.00
# 8
# 640GB
# $80.00
# Pro Account
# PRO
# A monthly subscription to access powerful features.
# →
# Get Pro
# ($9/month)
# ZeroGPU
# : Get 5x usage quota and highest GPU queue priority
# Spaces Hosting
# : Create ZeroGPU Spaces with A100 hardware
# Spaces Dev Mode
# : Fast iterations via SSH/VS Code for Spaces
# Inference Providers
# : Get $2 included credits across all Inference Providers
# Dataset Viewer
# : Activate it on private datasets
# Blog Articles
# : Publish articles to the Hugging Face blog
# Social Posts
# : Share short updates with the community
# Features Preview
# : Get early access to upcoming
# 										features
# PRO
# Badge
# :
# 										Show your support on your profile
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LLM Inference on Edge: A Fun and Easy Guide to run LLMs via React Native on your Phone!
# By
# medmekk
# March 7, 2025
# •
# 16
# Community Articles
# view all
# Getting Started With Hugging Face in 10 Minutes
# By
# proflead
# •
# about 1 hour ago
# •
# 1
# How to choose your AI model
# By
# MichielBontenbal
# •
# about 7 hours ago
# Introducing EuroBERT: A High-Performance Multilingual Encoder Model
# By
# EuroBERT
# and 3 others
# •
# about 8 hours ago
# •
# 69
# 🦸🏻#13: Action! How AI Agents Execute Tasks with UI and API Tools
# By
# Kseniase
# •
# about 12 hours ago
# •
# 1
# My Learning Journey: Understanding C
# By
# herooooooooo
# •
# about 21 hours ago
# •
# 3
# 🦸🏻#12: How Do Agents Learn from Their Own Mistakes? The Role of Reflection in AI
# By
# Kseniase
# •
# 1 day ago
# •
# 4
# What changed in the Transformer architecture
# By
# rishiraj
# •
# 1 day ago
# •
# 11
# 🌌 Synergistic Cognition & The Dalí AI Ganzfeld Experiment
# By
# TheMindExpansionNetwork
# •
# 3 days ago
# •
# 1
# 🌌 Synergistic Cognition: Master Plan White Paper - ALPHA UPDATED
# By
# TheMindExpansionNetwork
# •
# 3 days ago
# Beyond Python: AI Agents in JavaScript with KaibanJS
# By
# darielnoel
# •
# 4 days ago
# Everything You Need to Know about Knowledge Distillation
# By
# Kseniase
# and 1 other
# •
# 4 days ago
# •
# 14
# Atlaset Dataset for Moroccan Darija: From Data Collection, Analysis, to Model Trainings
# By
# atlasia
# and 1 other
# •
# 4 days ago
# •
# 18
# Manus AI: The Best Autonomous AI Agent Redefining Automation and Productivity
# By
# LLMhacker
# •
# 5 days ago
# •
# 109
# Private Synthetic Data Generation Made Easy: Out-of-the-Box with Docker, Argilla & Ollama
# By
# daqc
# and 1 other
# •
# 5 days ago
# •
# 4
# Forget Waiting: We Need a Hyper-Interactive Economy, and We Need it Yesterday.
# By
# fuzzy-mittenz
# •
# 5 days ago
# Map Features in OpenStreetMap with Computer Vision
# By
# mozilla-ai
# •
# 5 days ago
# •
# 6
# Fine-Tuning SigLIP 2 for Single Label Image Classification
# By
# prithivMLmods
# •
# 5 days ago
# •
# 14
# Deepseek R1 Robotic Reasoning with Checkers
# By
# codyreading
# and 4 others
# •
# 5 days ago
# •
# 14
# DiffRhythm: Revolutionizing Open Source AI Music Generator
# By
# Dzkaka
# •
# 6 days ago
# •
# 6
# Arabic AI Benchmarks and Leaderboards
# By
# silma-ai
# •
# 6 days ago
# •
# 9
# Hugging Face and JFrog partner to make AI Security more transparent
# By
# mcpotato
# March 4, 2025
# •
# 18
# A Deepdive into Aya Vision: Advancing the Frontier of Multilingual Multimodality
# By
# saurabhdash
# March 4, 2025
# guest
# •
# 57
# Trace & Evaluate your Agent with Arize Phoenix
# By
# m-ric
# February 28, 2025
# guest
# •
# 29
# HuggingFace, IISc partner to supercharge model building on India's diverse languages
# By
# visruth-rf
# February 27, 2025
# •
# 13
# FastRTC: The Real-Time Communication Library for Python
# By
# freddyaboulton
# February 25, 2025
# •
# 132
# Remote VAEs for decoding with HF endpoints 🤗
# By
# hlky
# February 24, 2025
# •
# 34
# SigLIP 2: A better multilingual vision language encoder
# By
# ariG23498
# February 21, 2025
# •
# 128
# SmolVLM2: Bringing Video Understanding to Every Device
# By
# orrzohar
# February 20, 2025
# guest
# •
# 199
# PaliGemma 2 Mix - New Instruction Vision Language Models by Google
# By
# ariG23498
# February 19, 2025
# •
# 63
# Introducing Three New Serverless Inference Providers: Hyperbolic, Nebius AI Studio, and Novita 🔥
# By
# reach-vb
# February 18, 2025
# •
# 93
# Welcome Fireworks.ai on the Hub 🎆
# By
# julien-c
# February 14, 2025
# •
# 55
# Fixing Open LLM Leaderboard with Math-Verify
# By
# hynky
# February 14, 2025
# •
# 26
# 1 Billion Classifications
# By
# derek-thomas
# February 13, 2025
# guest
# •
# 42
# From Chunks to Blocks: Accelerating Uploads and Downloads on the Hub
# By
# jsulz
# February 12, 2025
# •
# 49
# Previous
# 1
# 2
# 3
# ...
# 39
# Next
# Community Articles
# view all
# Getting Started With Hugging Face in 10 Minutes
# By
# proflead
# •
# about 1 hour ago
# •
# 1
# How to choose your AI model
# By
# MichielBontenbal
# •
# about 7 hours ago
# Introducing EuroBERT: A High-Performance Multilingual Encoder Model
# By
# EuroBERT
# and 3 others
# •
# about 8 hours ago
# •
# 69
# 🦸🏻#13: Action! How AI Agents Execute Tasks with UI and API Tools
# By
# Kseniase
# •
# about 12 hours ago
# •
# 1
# My Learning Journey: Understanding C
# By
# herooooooooo
# •
# about 21 hours ago
# •
# 3
# 🦸🏻#12: How Do Agents Learn from Their Own Mistakes? The Role of Reflection in AI
# By
# Kseniase
# •
# 1 day ago
# •
# 4
# What changed in the Transformer architecture
# By
# rishiraj
# •
# 1 day ago
# •
# 11
# 🌌 Synergistic Cognition & The Dalí AI Ganzfeld Experiment
# By
# TheMindExpansionNetwork
# •
# 3 days ago
# •
# 1
# 🌌 Synergistic Cognition: Master Plan White Paper - ALPHA UPDATED
# By
# TheMindExpansionNetwork
# •
# 3 days ago
# Beyond Python: AI Agents in JavaScript with KaibanJS
# By
# darielnoel
# •
# 4 days ago
# Everything You Need to Know about Knowledge Distillation
# By
# Kseniase
# and 1 other
# •
# 4 days ago
# •
# 14
# Atlaset Dataset for Moroccan Darija: From Data Collection, Analysis, to Model Trainings
# By
# atlasia
# and 1 other
# •
# 4 days ago
# •
# 18
# Manus AI: The Best Autonomous AI Agent Redefining Automation and Productivity
# By
# LLMhacker
# •
# 5 days ago
# •
# 109
# Private Synthetic Data Generation Made Easy: Out-of-the-Box with Docker, Argilla & Ollama
# By
# daqc
# and 1 other
# •
# 5 days ago
# •
# 4
# Forget Waiting: We Need a Hyper-Interactive Economy, and We Need it Yesterday.
# By
# fuzzy-mittenz
# •
# 5 days ago
# Map Features in OpenStreetMap with Computer Vision
# By
# mozilla-ai
# •
# 5 days ago
# •
# 6
# Fine-Tuning SigLIP 2 for Single Label Image Classification
# By
# prithivMLmods
# •
# 5 days ago
# •
# 14
# Deepseek R1 Robotic Reasoning with Checkers
# By
# codyreading
# and 4 others
# •
# 5 days ago
# •
# 14
# DiffRhythm: Revolutionizing Open Source AI Music Generator
# By
# Dzkaka
# •
# 6 days ago
# •
# 6
# Arabic AI Benchmarks and Leaderboards
# By
# silma-ai
# •
# 6 days ago
# •
# 9
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# join page
# Webpage Title:
# No title found
# Webpage Contents:
#
#
#
#
# community page
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# Advice for locally run AI Assistant
# Beginners
# 5
# 10
# March 10, 2025
# Data Economy Research
# 🤗Datasets
# 0
# 6
# March 10, 2025
# Sharing ArrowDataset with subfolders
# 🤗Datasets
# 1
# 2
# March 10, 2025
# Zoltan's FLOPs – GPU mini-grant, 1st iteration
# Research
# 0
# 3
# March 10, 2025
# How long does it take to verify a payment?
# Beginners
# 1
# 6
# March 10, 2025
# Space is stuck for hours in build state
# Spaces
# 3
# 5
# March 10, 2025
# Can't access HF discord after verification, been trying over a month
# Community Calls
# 17
# 146
# March 10, 2025
# Debit card payment hold issue
# Beginners
# 5
# 176
# March 10, 2025
# Request for FaceDancer Model on Hugging Face
# Models
# 1
# 13
# March 10, 2025
# Hugging Face Payment Error 402 & You've Exceeded Monthly Quota
# Languages at Hugging Face
# 1
# 17
# March 10, 2025
# UnexpectedError LFS Storage Used on the dataset has suddenly gone to -55034619833 Bytes
# 🤗Datasets
# 1
# 16
# March 10, 2025
# Payment Processed but PRO Subscription Not Activated
# Beginners
# 6
# 21
# March 10, 2025
# My Space building is never finish
# Beginners
# 3
# 9
# March 10, 2025
# New ArXiv Daily Newsletter Tool - SciSummarize
# Research
# 0
# 6
# March 10, 2025
# Custom dataset fails. "Please pass features or at least one example when writing data"
# Beginners
# 1
# 3
# March 10, 2025
# Git submodules in HuggingFace Spaces app
# Spaces
# 1
# 7
# March 9, 2025
# ValueError: You are trying to offload the whole model to the disk. Please use the `disk_offload` function instead
# Beginners
# 8
# 9373
# March 10, 2025
# Unable to run Application
# Beginners
# 2
# 11
# March 8, 2025
# Running LLM on Android
# Beginners
# 1
# 32
# March 9, 2025
# Does the model "Qwen/Qwen2.5-Coder-32B-Instruct" free?
# Course
# 1
# 18
# March 9, 2025
# ZeroGPU illegal duration. The requested GPU duration (300s) is larger than the maximum allowed
# Spaces
# 5
# 42
# March 9, 2025
# Guidance on getting started with fine tuned uncensored model
# Beginners
# 2
# 39
# March 8, 2025
# Recommended max size of dataset?
# 🤗Datasets
# 3
# 8
# March 9, 2025
# Unable to access public model - status 401
# Models
# 6
# 18
# March 10, 2025
# Best way to quickly switch ControlNet without affecting other components?
# Beginners
# 2
# 6
# March 9, 2025
# When is the Chinese translation of deep-rl-course expected to be available to the public
# Study Groups
# 0
# 7
# March 9, 2025
# Injecting Multiple Modalities into a Transformer Decoder via Cross-Attention
# 🤗Transformers
# 1
# 4
# March 9, 2025
# Fine-Tuning + RAG based Chatbot: Dataset Structure & Instruction Adherence Issues
# Intermediate
# 6
# 78
# March 10, 2025
# Why is my DistilBERT model performing poorly on some classes despite hyperparameter tuning?
# Beginners
# 15
# 46
# March 9, 2025
# Hi has anyone posted a Deepseek R1 that is abliterated in the 671B?
# Beginners
# 7
# 52
# March 9, 2025
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
#
#
#
# GitHub page
# Webpage Title:
# Hugging Face · GitHub
# Webpage Contents:
# Skip to content
# Navigation Menu
# Toggle navigation
# Sign in
# huggingface
# Product
# GitHub Copilot
# Write better code with AI
# Security
# Find and fix vulnerabilities
# Actions
# Automate any workflow
# Codespaces
# Instant dev environments
# Issues
# Plan and track work
# Code Review
# Manage code changes
# Discussions
# Collaborate outside of code
# Code Search
# Find more, search less
# Explore
# All features
# Documentation
# GitHub Skills
# Blog
# Solutions
# By company size
# Enterprises
# Small and medium teams
# Startups
# Nonprofits
# By use case
# DevSecOps
# DevOps
# CI/CD
# View all use cases
# By industry
# Healthcare
# Financial services
# Manufacturing
# Government
# View all industries
# View all solutions
# Resources
# Topics
# AI
# DevOps
# Security
# Software Development
# View all
# Explore
# Learning Pathways
# Events & Webinars
# Ebooks & Whitepapers
# Customer Stories
# Partners
# Executive Insights
# Open Source
# GitHub Sponsors
# Fund open source developers
# The ReadME Project
# GitHub community articles
# Repositories
# Topics
# Trending
# Collections
# Enterprise
# Enterprise platform
# AI-powered developer platform
# Available add-ons
# Advanced Security
# Enterprise-grade security features
# Copilot for business
# Enterprise-grade AI features
# Premium Support
# Enterprise-grade 24/7 support
# Pricing
# Search or jump to...
# Search code, repositories, users, issues, pull requests...
# Search
# Clear
# Search syntax tips
# Provide feedback
# We read every piece of feedback, and take your input very seriously.
# Include my email address so I can be contacted
# Cancel
# Submit feedback
# Saved searches
# Use saved searches to filter your results more quickly
# Cancel
# Create saved search
# Sign in
# Sign up
# Reseting focus
# You signed in with another tab or window.
# Reload
# to refresh your session.
# You signed out in another tab or window.
# Reload
# to refresh your session.
# You switched accounts on another tab or window.
# Reload
# to refresh your session.
# Dismiss alert
# Hugging Face
# The AI community building the future.
# Verified
# We've verified that the organization
# huggingface
# controls the domain:
# huggingface.co
# Learn more about verified organizations
# 46k
# followers
# NYC + Paris
# https://huggingface.co/
# X
# @huggingface
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# 0
# More
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# Pinned
# Loading
# transformers
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# Python
# 141k
# 28.2k
# diffusers
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# Python
# 27.9k
# 5.7k
# datasets
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for ML models with fast, easy-to-use and efficient data manipulation tools
# Python
# 19.8k
# 2.8k
# peft
# peft
# Public
# 🤗 PEFT: State-of-the-art Parameter-Efficient Fine-Tuning.
# Python
# 17.7k
# 1.8k
# accelerate
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# Python
# 8.5k
# 1k
# optimum
# optimum
# Public
# 🚀 Accelerate inference and training of 🤗 Transformers, Diffusers, TIMM and Sentence Transformers with easy to use hardware optimization tools
# Python
# 2.8k
# 508
# Repositories
# Loading
# Type
# Select type
# Forks
# Archived
# Mirrors
# Templates
# Language
# Select language
# All
# C
# C#
# C++
# Cuda
# Dockerfile
# Go
# Handlebars
# HTML
# Java
# JavaScript
# Jupyter Notebook
# Kotlin
# Lua
# MDX
# Mustache
# Nix
# Python
# Rust
# Shell
# Smarty
# Swift
# TypeScript
# Sort
# Select order
# Last updated
# Name
# Stars
# Showing 10 of 298 repositories
# huggingface_hub
# Public
# The official Python client for the Huggingface Hub.
# huggingface/huggingface_hub’s past year of commit activity
# Python
# 2,412
# Apache-2.0
# 650
# 150
# (5 issues need help)
# 24
# Updated
# Mar 10, 2025
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# huggingface/transformers’s past year of commit activity
# Python
# 140,932
# Apache-2.0
# 28,231
# 1,017
# (2 issues need help)
# 595
# Updated
# Mar 10, 2025
# lerobot
# Public
# 🤗 LeRobot: Making AI for Robotics more accessible with end-to-end learning
# huggingface/lerobot’s past year of commit activity
# Python
# 9,633
# Apache-2.0
# 1,085
# 134
# 114
# Updated
# Mar 10, 2025
# huggingface.js
# Public
# Utilities to use the Hugging Face Hub API
# huggingface/huggingface.js’s past year of commit activity
# TypeScript
# 1,544
# MIT
# 316
# 96
# (5 issues need help)
# 47
# Updated
# Mar 10, 2025
# optimum-neuron
# Public
# Easy, fast and very cheap training and inference on AWS Trainium and Inferentia chips.
# huggingface/optimum-neuron’s past year of commit activity
# Jupyter Notebook
# 219
# Apache-2.0
# 70
# 19
# 10
# Updated
# Mar 10, 2025
# text-generation-inference
# Public
# Large Language Model Text Generation Inference
# huggingface/text-generation-inference’s past year of commit activity
# Python
# 9,864
# Apache-2.0
# 1,162
# 213
# 29
# Updated
# Mar 10, 2025
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# huggingface/accelerate’s past year of commit activity
# Python
# 8,450
# Apache-2.0
# 1,047
# 101
# (2 issues need help)
# 27
# Updated
# Mar 10, 2025
# huggingface-inference-toolkit
# Public
# Hugging Face Inference Toolkit used to serve transformers, sentence-transformers, and diffusers models.
# huggingface/huggingface-inference-toolkit’s past year of commit activity
# Python
# 63
# Apache-2.0
# 13
# 6
# 3
# Updated
# Mar 10, 2025
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# huggingface/diffusers’s past year of commit activity
# Python
# 27,945
# Apache-2.0
# 5,746
# 431
# (10 issues need help)
# 175
# Updated
# Mar 10, 2025
# text-generation-inference-nix
# Public
# huggingface/text-generation-inference-nix’s past year of commit activity
# Nix
# 6
# 4
# 0
# 1
# Updated
# Mar 10, 2025
# View all repositories
# People
# View all
# Top languages
# Python
# Jupyter Notebook
# Rust
# TypeScript
# JavaScript
# Most used topics
# pytorch
# machine-learning
# nlp
# transformers
# deep-learning
# Footer
# © 2025 GitHub, Inc.
# Footer navigation
# Terms
# Privacy
# Security
# Status
# Docs
# Contact
# Manage cookies
# Do not share my personal information
# You can’t perform that action at this time.
#
#
#
# LinkedIn page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# Discover all 502 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Bassem ASSEH
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# See all employees
# Updates
# Hugging Face
# reposted this
# Freddy Boulton
# Software Engineer @ 🤗
# 3d
# Edited
# Report this post
# Next.js
# + FastRTC: Production Audio Streaming Made Simple 🚀
#
# Check out this impressive demo by Rohan showcasing seamless integration between FastRTC and @nextjs!
#
# The video demonstrates:
# • Beautiful UI components built with
# Next.js
# • Production-grade WebRTC server powered by FastRTC
# • How to integrate FastRTC with any UI framework
#
# Building production audio streaming applications in Python has never been easier. The complete code is available on GitHub -
# https://lnkd.in/egd4u6Va
# kudos
# Rohan Richard
# …more
# 118
# 5 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 58,296 followers
# 4d
# Edited
# Report this post
# Diffusion Self-Distillation (DSD) for zero-shot Image customization! 🔥
#
# Get Fine-grained Control over the text-to-image diffusion process.
#
# What DSD can do for you 🤩  -
# > Character Preservation
# > Item Preservation
# > Instruction Prompting
# > Relighting
# > Comic Generation
#
# Official App is live on
# Hugging Face
# :
# https://lnkd.in/gUvX-XEW
# …more
# 203
# 5 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Sayak Paul
# ML @ Hugging Face 🤗
# 5d
# Report this post
# Added inference-time scaling support for two video models in my repo: LTX-Video & Wan 📽️
#
# Currently, we only support LAION aesthetic scoring as the reward, but other available reward models in the repo will be supported soon.
#
# The result below is from Wan-1.3B and with the following prompt:
# "Two anthropomorphic cats in comfy boxing gear and bright gloves fight intensely on a spotlighted stage."✍️
#
# Check out the links below for more info and more results:
#
# 1> Repo:
# https://lnkd.in/gPRDz7KB
# 2> PR:
# https://lnkd.in/gjHzEwDg
# …more
# 109
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Aritra Roy Gosthipaty
# 1w
# Report this post
# What the hell! The diffusers team just dropped: Remote VAEs for decoding.
#
# What’s that? A way to generate images and videos without frying your GPU. Let’s unpack this!
#
# Normally, decoding high-res images or videos with diffusion models eats memory. On a regular GPU, it’s slow or crashes.
#
# Remote VAEs send that heavy lifting to a cloud endpoint.
#
# How?
#
# You generate the latent locally, then a remote server decodes it into the final image or video. No data stored, all open-source. Slick, right?
#
#
# Why it matters: You can queue multiple jobs.
#
# While one video decodes, start another. It’s like streaming your AI workload—faster, cheaper, no monster rig needed.
#
#
# Use cases? Indie devs making games, artists churning out visuals, researchers testing models—all without begging for a supercomputer.
#
# Democratizing AI, one decode at a time.
#
#
#  Downsides?
#
# You need internet, and there’s a tiny delay for cloud calls. But for most, it’s a small price for not melting your hardware. Thoughts—what would YOU build with this?
#
# Kudos to
# Sayak Paul
# & Rhys for this!
# …more
# 227
# 11 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Freddy Boulton
# Software Engineer @ 🤗
# 5d
# Report this post
# LLMs can sometimes talk too much 🗣️ Now you can interrupt them!
#
# Introducing our biggest FastRTC update yet: agent interruption!
#
# Now in FastRTC, you can mute your AI mid-response and ask a follow-up question. Just like a natural conversation.
#
# The video shows it in action - ask a new question while the LLM is speaking, and it immediately switches to answering your new query.
#
# Update to version 0.0.11 to try it today! Huge thanks to everyone who requested this feature.
# 287
# 12 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Freddy Boulton
# Software Engineer @ 🤗
# 1w
# Report this post
# 🗣️ Edit documents with just your voice!
#
# Built with FastRTC +
# SambaNova Systems
# …more
# 132
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 58,296 followers
# 1w
# Report this post
# This is BIG! 🚀 We Are Bridging The Language Gap: JavaScript Speed in Python Environments!
#
# Every developer knows the challenge: You want Python's simplicity AND JavaScript's client-side performance.
#
# Introducing Groovy from Gradio - a focused Python-to-JavaScript transpiler that delivers exactly that:
#
# ✅ Write functions in familiar Python syntax
# ✅ Run them with JavaScript's client-side speed ⚡
# ✅ Receive clear error messages when code can't be transpiled
#
# We are NOT attempting to replace JavaScript - Groovy prioritizes transparency over complete language coverage, making it a practical tool rather than a theoretical exercise.
#
# For teams building with Gradio, this means maintaining one codebase while achieving the performance benefits of client-side execution.
#
# Who else is excited about tools that reduce context-switching in development workflows?
# 519
# 28 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning Advocacy @ 🤗 Hugging Face
# 1w
# Edited
# Report this post
# New Course on how to build models like Deepseek R1!
#
# It’s called The Reasoning Course and it's FREE and CERTIFIED. To sign up just follow the org:
#
# 🔗
# https://lnkd.in/enr3adQ5
# This is what the course will cover:
# - It will teach you to build your own reasoning model like Deepseek r1.
# - It’s suitable for code and non-coders with separate certification.
# - The course has material and exercises from
# Hugging Face
# ,
# Maxime Labonne
# ,
# Unsloth AI
# , and
# marimo
# .
#
# This is how the course works:
# - Sign up now, the first release is already live.
# - Each week we’ll release new material and exercises.
# - We have interactive demos, quizzes, and certifications
# 2,031
# 55 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 58,296 followers
# 1w
# Report this post
# Caricature to depth! 🤯
# https://lnkd.in/gG9Ka-7u
# …more
# 192
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 58,296 followers
# 1w
# Report this post
# Distill-Any-Depth app is live on
# Hugging Face
# ! 🔥🔥
#
# Read more in our previous post:
# https://lnkd.in/gSb3qfXi
# …more
# 150
# 1 Comment
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Mistral AI
# Technology, Information and Internet
# Paris, France
# Perplexity
# Software Development
# San Francisco, California
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# DeepLearning.AI
# Software Development
# Palo Alto, California
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# Google DeepMind
# Research Services
# London, London
# Cohere
# Software Development
# Toronto, Ontario
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Your California Privacy Choices
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app
#
#
#
# Twitter page
# Webpage Title:
# twitter.com | 524: A timeout occurred
# Webpage Contents:
# A timeout occurred
# Error code 524
# Visit
# cloudflare.com
# for more information.
# 2025-03-10 15:49:12 UTC
# You
# Browser
# Working
# Minneapolis
# Cloudflare
# Working
# twitter.com
# Host
# Error
# What happened?
# The origin web server timed out responding to this request.
# What can I do?
# If you're a visitor of this website:
# Please try again in a few minutes.
# If you're the owner of this website:
# The connection to the origin web server was made, but the origin web server timed out before responding. The likely cause is an overloaded background task, database or application, stressing the resources on your web server. To resolve, please work with your hosting provider or web development team to free up resources for your database or overloaded application.
# Additional troubleshooting information here.
# Cloudflare Ray ID:
# 91e3f37fb9de4c9a
# •
# Your IP:
# Click to reveal
# 173.18.51.54
# •
# Performance & security by
# Cloudflare

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog', 'url': 'https://huggingface.co/blog'}, {'type': 'news page', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nPosts\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\nQwen/QwQ-32B\nUpdated\nabout 1 hour ago\n•\n132k\n•\n1.81k\ndeepseek-ai/DeepSeek-R1\nUpdated\n15 days ago\n•\n3.43M\n•\n11.1k\nmicrosoft/Phi-4-multimodal-instruct\nUpdated\n3 days ago\n•\n303k\n•\n1.06k\nWan-AI/Wan2.1-T2V-14B\nUpdated\n12 days ago\n•\n191k\n•\n964\nCohereForAI/aya-vision-8b\nUpdated\n6 days ago\n•\n144k\n•\n220\nBrowse 1M+ models\nSpaces\nRunning\non\nZero\n337\n337\nDi♪♪Rhythm\n🎶\nBlazingly Fast and Embarrassingly Simple Song Generation\nRunning\n1.06k\n1.06k\nWan2.1\n💻\nWan: Open and Advanced Large-Scale Video Generative Models\nRunning\n2.17k\n2.17k\nThe Ultra-Scale Playbook\n🌌\nThe ultimate guide to training LLM on large GPU Clusters\nRunning\n278\n278\nQwQ 32B Demo\n🌖\nGenerate text responses based on user input\nRunning\non\nZero\n7.74k\n7.74k\nFLUX.1 [dev]\n🖥\nGenerate images from text prompts\nBrowse 400k+ applications\nDatasets\nfacebook/natural_reasoning\nUpdated\n17 days ago\n•\n9.01k\n•\n362\nFreedomIntelligence/medical-o1-reasoning-SFT\nUpdated\n16 days ago\n•\n26.7k\n•\n406\nCongliu/Chinese-DeepSeek-R1-Distill-data-110k\nUpdated\n18 days ago\n•\n6.87k\n•\n489\nGeneralReasoning/GeneralThought-195K\nUpdated\nabout 3 hours ago\n•\n697\n•\n59\nKodCode/KodCode-V1\nUpdated\nabout 19 hours ago\n•\n2.19k\n•\n55\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nEnterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n391 models\n•\n2.76k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.07k models\n•\n5k followers\nAmazon\ncompany\n•\n20 models\n•\n2.83k followers\nGoogle\ncompany\n•\n959 models\n•\n8.65k followers\nIntel\ncompany\n•\n219 models\n•\n2.32k followers\nMicrosoft\ncompany\n•\n362 models\n•\n10.1k followers\nGrammarly\nEnterprise\ncompany\n•\n10 models\n•\n133 followers\nWriter\nEnterprise\ncompany\n•\n20 models\n•\n248 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n140,930\nState-of-the-art ML for PyTorch, TensorFlow, JAX\nDiffusers\n27,945\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,157\nSafe way to store/distribute neural network weights\nHub Python Library\n2,412\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,454\nFast tokenizers optimized for research & production\nTRL\n12,381\nTrain transformers LMs with reinforcement learning\nTransformers.js\n13,166\nState-of-the-art ML running directly in your browser\nsmolagents\n14,260\nSmol library to build great agents in Python\nPEFT\n17,691\nParameter-efficient finetuni ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'company social page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'company social page', 'url': 'https://twitter.com/huggingface'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}]}
# # Hugging Face Brochure
#
# ---
#
# ## About Us
#
# **Hugging Face** is at the forefront of the AI community, dedicated to building the future of machine learning. Our collaborative platform empowers developers, researchers, and organizations to come together to share, discover, and innovate with AI models, datasets, and applications. With over 1 million models accessible and numerous cutting-edge tools, we are making AI more accessible and impactful.
#
# ---
#
# ## Our Offerings
#
# ### **Models and Datasets**
# - **Browse and Collaborate**: Over 1 million models and 250,000 datasets are available for collaboration and experimentation.
# - **Popular Models**: Includes state-of-the-art models like Qwen/QwQ-32B and Microsoft’s Phi-4-multimodal-instruct.
#
# ### **Spaces and Applications**
# - **Running Applications**: From song generation to image text generation, our Spaces host diverse applications that allow users to interact with AI creatively.
# - **AI Apps**: Explore a wide range of applications across different modalities: text, image, video, audio, and even 3D.
#
# ### **Enterprise Solutions**
# - **Advanced Platform**: Our enterprise offering provides advanced security, access controls, priority support, and tailored solutions for organizations needing commercial deployment of AI.
#
# ---
#
# ## Company Culture
#
# At Hugging Face, we foster a **community-driven** environment that encourages exploration, creativity, and collaboration. Our team is made up of passionate individuals who are committed to pushing the boundaries of what's possible with AI. We celebrate contributions from our users and are focused on building tools that benefit everyone in the machine learning community.
#
# ### **Core Values**
# - **Collaboration**: Working together across the globe to share knowledge and technology.
# - **Open Source**: Committed to open-source principles by providing a platform for innovators to contribute.
# - **Innovation**: Encouraging experimentation and new ideas to drive advancements in AI.
#
# ---
#
# ## Join Us
#
# ### **Careers at Hugging Face**
# We are constantly looking for talented professionals who share our passion for AI and machine learning. If you are interested in joining us, we invite you to explore available positions ranging from technical roles to community management.
#
# #### Why Work with Us?
# - Be part of a cutting-edge community making significant strides in AI technology.
# - Work with an inclusive team that values diverse perspectives and ideas.
# - Participate in impactful projects that shape the future of AI.
#
# ---
#
# ## Our Customers
#
# Hugging Face proudly supports **over 50,000 organizations** from various industries, including notable names such as:
# - **Meta**
# - **Amazon**
# - **Microsoft**
# - **Google**
# - **Grammarly**
#
# Together, we are building powerful AI solutions that benefit businesses and communities alike.
#
# ---
#
# For more information, visit our website: [Hugging Face](https://huggingface.co)
# Follow us on [Twitter](https://twitter.com/huggingface) and [GitHub](https://github.com/huggingface) to stay updated!
#
# ---
#
# ### "The AI community building the future."

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face Brochure
#
# ### Welcome to Hugging Face
#
# **The AI Community Building the Future**
#
# Hugging Face is a collaborative platform designed for the machine learning community, where members can discover, create, and share cutting-edge models, datasets, and applications. With over **1 million models** and **250,000 datasets**, you can harness state-of-the-art technology to propel your projects to new heights.
#
# ---
#
# ### Company Culture
#
# At Hugging Face, we foster an inclusive and innovative atmosphere where everyone is encouraged to contribute to the AI discipline. Our community is built on collaboration, learning, and open-source principles. We believe in the power of collective intelligence and are committed to building tools that empower AI developers of all skill levels.
#
# ---
#
# ### Our Customers
#
# More than **50,000 organizations** leverage Hugging Face’s ecosystem, including renowned enterprises such as:
#
# - **Meta**
# - **Amazon**
# - **Google**
# - **Microsoft**
# - **Intel**
#
# These partnerships highlight the trust and reliability associated with our platform, making Hugging Face a crucial player in the AI landscape.
#
# ---
#
# ### Careers & Job Opportunities
#
# Hugging Face is on a mission to expand its team as we grow. We are constantly looking for talented individuals passionate about AI and technology. Our employees enjoy a dynamic work environment that encourages creativity, flexibility, and personal growth. If you're interested in contributing to the future of machine learning, consider joining us!
#
# **Explore current openings:** [Careers at Hugging Face](https://huggingface.co).
#
# ---
#
# ### Features & Offerings
#
# - **Explore AI Apps**: Collaborate on innovative applications through our user-friendly interfaces.
# - **Models & Datasets**: Access a vast library of resources to power your AI applications.
# - **Enterprise Solutions**: Harness our optimized compute capabilities and enterprise-level enhancements, including priority support and secure access controls.
#
# ---
#
# ### Join the Movement
#
# Whether you're a seasoned developer, a curious newcomer, or a potential investor, Hugging Face welcomes you to explore, collaborate, and innovate within our flourishing community.
#
# **Get Started Today**: [Join Hugging Face](https://huggingface.co)
#
# ---
#
# *Together, we’re building the future of AI.*

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
